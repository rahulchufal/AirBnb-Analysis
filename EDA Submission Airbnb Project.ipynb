# %% [markdown]
# # **Project Name**    - **AirBnb Booking Analysis**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# My name is Rahul Chufal and I am going to analyse the complete data of AirBnb  Booking of 2019. In this project I am working on the Airbnb NYC 2019.csv file. This is a very interesting project to work with and the main objective is perform Exploratory Data Analysis on the given dataset and draw useful conclusions about general trends in AirBnb bookings and how factors governing hotel bookings
#
# The dataset given is a dataset from Airbnb, which is a company operating an online marketplace for short-term homestays and experiences. The company acts as a broker and charges a commission from each booking. we have to analysis the data to understand the business, understanding the behavior of customers and hosts so we can improve its performance and services and take the necessary steps needed accordingly.
#
# ## **Dataset Description**
# Name of the csv file:  Airbnb NYC 2019.csv
#
#
#
# ##   **Description about dataset columns:**
# The above dataset has 48895 rows and 16 columns. There are no missing values or duplicate values in the dataset.
#
# * **Name** : It represents  name of the Hotel
# * **Host Id** : It represents Unique id give to every host of the property
# * **Host Name** : It represents the name of host of that hostel
# * **Neighbourhood Group** :It represents  Neighbourhood group of the property
# * **Neighbourhood** : It represents Neighbourhood of the property
# * **Latitude** : It represents latitude of the property
# * **Longitude** : It represents longitude of the property
# * **Room_type** : It represents Which type of room it is
# * **Price** : It represents total price of room
# * **Minimum Nights** :It represents minimum number of nights customer can book for
# * **Number Of Reviews** : It represents number of reviews given by customers
# * **Last Review** : It represents the date of the last review by customer
# * **Reviews Per Month** It represents No of reviews given by customers per month
# * **Calculated Host Listings Count** It represents Total Count of host listing
# * **Availability 365** It represents Number of days room available in a year
#
# And i worked on only 15 columns.
#
# ## **Data wrangling**
# ### <b> Cleaning data </b>
#
# Cleaning data is crucial step before EDA as it will remove the ambigous data that can affect the outcome of EDA.
#
# While cleaning data we will perform following steps: \
# 1) Remove duplicate rows  \
# 2) Handling missing values.  \
# 3) Convert columns to appropriate datatypes.  \
# 4) Adding important columns
#
# ## **Important libraries**
#
# In this exploratory analysis the following libraries has used:-
#
#
# **Numpy**
#
# **Pandas**
#
# **Matplotlib**
#
# **Seaborn**
#
# **Plotly**
#
# ## **Following Graphs & plots has used and their descriptions:**
#
# 1. **Line plot** displays data as points or check marks above a number line, showing the frequency of each value.
#
# 2. **Bar plots**  should be used when you are showing segments of information. Vertical bar charts are useful to compare different categorical or discrete variables.
#
# 3. **Pie plot** helps organise and show data as a percentage of a whole.
#
# 4. **Donut plot** shows the relationship of parts to a whole, but a donut chart can contain more than one data series.
#
# 5. **Countplot** is used to represent the occurrence(counts) of the observation present in the categorical variable.
#
# 6. **histogram** showing frequency distributions. It is a graph showing the number of observations within each given interval.
# 7. **heatmap** it is defined as a graphical representation of data using colors to visualize the value of the matrix
#
# ## **following Different types of Analysis has done:-**
# 1. Booking Time Analysis.
# 2.Revenue Analysis By Months.
# 3.Booking by different types of Customers Analysis.
# 4.Market Segment Analysis
# 5.Special Requests Analysis.
# 6.Booking Cancellation Analysis.
# 7.Hotel wise bookings analysis.
# 8.Preference Analysis.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Airbnb is a leading online marketplace that connects people who need accommodation with hosts who have space to spare. While Airbnb has revolutionized the hospitality industry, it still faces various challenges that need to be addressed.
#
# One of the significant problems faced by Airbnb is the lack of transparency in the marketplace, which can lead to trust issues among guests and hosts.
#
# Another problem that Airbnb faces is the inconsistent quality of listings. Some listings may be luxurious and well-maintained, while others may be subpar and poorly managed. This inconsistency can lead to disappointment for guests and can damage Airbnb's reputation.
#
# Additionally, Airbnb faces challenges in ensuring that hosts and guests follow the rules and regulations set by local governments. In some cities, Airbnb listings are subject to strict regulations, and violations can result in hefty fines.
#
# To address these challenges, Airbnb needs to implement effective solutions that improve transparency, quality, and regulatory compliance. This project aims to explore various strategies that can help Airbnb enhance its marketplace and provide better experiences for hosts and guests.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The business objectives for the Airbnb project could include:
#
#
# 1. **Enhance the guest experience** : Airbnb's primary objective is to provide guests with a unique and comfortable experience. To achieve this, the platform needs to improve the quality of its listings, increase transparency, and provide better customer support.
#
# 2. **Increase host satisfaction** :  To ensure that hosts continue to list their properties on the platform, Airbnb needs to provide them with the necessary support and tools to manage their listings effectively. This includes offering transparent pricing, access to reliable cleaners and maintenance services, and effective communication channels.
#
# 3. **Expand the customer base** :  Airbnb's growth depends on attracting new customers to the platform. The company needs to increase its marketing efforts and reach out to new demographics to broaden its customer base.
#
# 4. **Ensure regulatory compliance** :  In many cities, Airbnb listings are subject to strict regulations, and violations can result in hefty fines. The platform needs to ensure that hosts and guests follow the rules and regulations set by local governments to avoid legal issues and maintain a positive reputation.
#
# 5. **Increase revenue** :  Airbnb is a business, and its ultimate objective is to generate revenue. The platform needs to increase its revenue streams by introducing new services, offering premium features, and expanding into new markets.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
# Import Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objs as go
# %matplotlib inline
from matplotlib import rcParams

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')

file_path = '/content/drive/MyDrive/dat/Airbnb NYC 2019.csv'
df=pd.read_csv(file_path)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print(df.shape)
print(f'There are {len(df)} rows and {len(df.columns)} Columns in this dataset.')

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
len(df[df.duplicated()])

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(df.isnull().sum())

# %% [markdown]
# ### Observations
# Columns like name,host_name,last_review,reviews_per_month have missing values. so here we will fill the columns like  name, host_name with random 'name' and 'host name' and we will drop the column last_review because its not much important for our dataset and we will fill the column reviews_per_month with zero so we can remove all the null values and clean our data.

# %%
# Here we will Drop the columns  last review
df.drop(['last_review'],inplace=True,axis=1)
#checking Missing Values/Null Values Count
df.isnull().sum()

# %%
# Here we will replace the null value in column name and hostname
df.fillna({'name':'name','host_name':'host name'},inplace=True)

# %%
# Now we will Replace the NaN values with zero
df.fillna({'reviews_per_month':0},inplace=True)
df.isnull().sum()

# %%
# Visualizing the missing values
# Checking Null Value by plotting Heatmap
sns.heatmap(df.isnull(), cbar=False)

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset given is a dataset from Airbnb, which is a company operating an online marketplace for short-term homestays and experiences. The company acts as a broker and charges a commission from each booking.
#
# we have to analysis the data to understand the business, understanding the behavior of customers and hosts so we can improve its performance and services and take the necessary steps needed accordingly.
#
#   The above dataset has 48895 rows and 16 columns. There are no missing values or duplicate values in the dataset.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
df.describe(include='all')
# Out:
#                   id            name       host_id host_name  \
# count   4.889500e+04           48895  4.889500e+04     48895
# unique           NaN           47906           NaN     11453
# top              NaN  Hillside Hotel           NaN   Michael
# freq             NaN              18           NaN       417
# mean    1.901714e+07             NaN  6.762001e+07       NaN
# std     1.098311e+07             NaN  7.861097e+07       NaN
# min     2.539000e+03             NaN  2.438000e+03       NaN
# 25%     9.471945e+06             NaN  7.822033e+06       NaN
# 50%     1.967728e+07             NaN  3.079382e+07       NaN
# 75%     2.915218e+07             NaN  1.074344e+08       NaN
# max     3.648724e+07             NaN  2.743213e+08       NaN
#
#        neighbourhood_group neighbourhood      latitude     longitude  \
# count                48895         48895  48895.000000  48895.000000
# unique                   5           221           NaN           NaN
# ...

# %% [markdown]
# ###Observation
# after observing the data closly we got to know that The Minimum 'Price' of room  is 0 which is not possible and The Maximum  value of 'minimum_nights' is 1250 which is also not possible , so here we will replace the 'price' having value zero with the minimun price and we will replace the 'minimum nights'  column having value more than 365 with the max value 365 days of a year.

# %%
#Check the rows which have 'price'=0
df[df['price']==0]
# Out:
#              id                                               name    host_id  \
# 23161  18750597  Huge Brooklyn Brownstone Living, Close to it all.    8993084
# 25433  20333471      ★Hostel Style Room | Ideal Traveling Buddies★  131697576
# 25634  20523843    MARTIAL LOFT 3: REDEMPTION (upstairs, 2nd room)   15787004
# 25753  20608117                    Sunny, Quiet Room in Greenpoint    1641537
# 25778  20624541      Modern apartment in the heart of Williamsburg   10132166
# 25794  20639628  Spacious comfortable master bedroom with nice ...   86327101
# 25795  20639792  Contemporary bedroom in brownstone with nice view   86327101
# 25796  20639914       Cozy yet spacious private brownstone bedroom   86327101
# 26259  20933849                              the best you can find   13709292
# 26841  21291569  Coliving in Brooklyn! Modern design / Shared room  101970559
# 26866  21304320             Best Coliving space ever! Shared room.  101970559
#
# ...

# %%
# now we will change the value of price with the above function
df['price']=df['price'].apply(lambda x: 100 if x==0 else x)

# %%
#now check the rows again which have 'price'=0
df[df['price']==0]
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []

# %%
#Now we will Change the  values of 'minimum_nights' to 365 which are greater than 365
df['minimum_nights']=df['minimum_nights'].apply(lambda x: 365 if x>365 else x)

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.743184
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.144546
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420     10.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       48895.000000
# mean         6.942980          23.274466           1.090910
# std         17.530294          44.550582           1.597283
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# * **Host Id** : Unique id give to every host of the property
# * **Neighbourhood Group** : neighbourhood group of the property
# * **Neighbourhood** : Neighbourhood of the property
# * **Latitude** : Latitude of the property
# * **Longitude** : Longitude of the property
# * **Room_type** : Type of room
# * **Price** : Total price of room
# * **Minimum Nights** :Minimum number of nights customer can book for
# * **Number Of Reviews** Number of reviews given by customers
# * **Reviews Per Month** No of reviews given by customers per month
# * **Calculated Host Listings Count** Total Count of host listing
# * **Availability 365** Number of days room available in a year

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
print(pd.unique(df['name']))

# %%
print(pd.unique(df['host_id']))

# %%
print(pd.unique(df['neighbourhood_group']))

# %%
print(pd.unique(df['neighbourhood']))

# %%
print(pd.unique(df['latitude']))

# %%
print(pd.unique(df['longitude']))

# %%
print(pd.unique(df['room_type']))

# %%
print(pd.unique(df['price']))

# %%
print(pd.unique(df['minimum_nights']))

# %%
print(pd.unique(df['number_of_reviews']))

# %%
print(pd.unique(df['reviews_per_month']))

# %%
print(pd.unique(df['calculated_host_listings_count']))

# %%
print(pd.unique(df['availability_365']))

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### **How many different types of room availabe ?**

# %%
# Finding unique values from column 'room_type'
room_type = df.room_type.unique()

# %%
room_type
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
#Finding the count of every room type
roomtype_frequency = dict(df.room_type.value_counts())
roomtype_frequency
# Out:
# {'Entire home/apt': 25409, 'Private room': 22326, 'Shared room': 1160}

# %%
roomtype_frequency
# Out:
# {'Entire home/apt': 25409, 'Private room': 22326, 'Shared room': 1160}

# %%
# Creating New Dataframe from dictionary
roomtype_frequency_df=pd.DataFrame(list(roomtype_frequency.items()),columns = ['Room_type', 'Count'])
roomtype_frequency_df
# Out:
#          Room_type  Count
# 0  Entire home/apt  25409
# 1     Private room  22326
# 2      Shared room   1160

# %%
# Creating Pie Chart
fig = px.pie(roomtype_frequency_df, values='Count', names='Room_type', title='Different Types Of Listed Rooms')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# we have used pie chart here because we got only 3 types of room type here and it will be easy for us to represent its count value using pie chart for better analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# after seeing the chart we can

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 2
# Total no. of nights spends per room types

# %%
# Finding unique values from column 'room_type'
room_type = df.room_type.unique()

# %%
room_type
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
#  find the maximum number of nights according to different room type
total_room=df.groupby('room_type')['minimum_nights'].sum().reset_index()
room_types=total_room.sort_values('minimum_nights',ascending=False)
room_types.head()
# Out:
#          room_type  minimum_nights
# 0  Entire home/apt          213472
# 1     Private room          119128
# 2      Shared room            6877

# %%
fig = px.bar(room_types, x='room_type', y='minimum_nights', text_auto='.2s',title="Total Number Of Minimum Nights According To The Type Of Room",width=500, height=600)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 3
# Find the top five hosts based on their turnover

# %%
#  find the maximum price across different host name
top_host=df.groupby(['host_name'])['price'].sum().reset_index()
top_host.rename(columns={'price':'total_price'},inplace=True)
top_host.head()
# Out:
#                   host_name  total_price
# 0                      'Cil          120
# 1           (Ari) HENRY LEE          140
# 2  (Email hidden by Airbnb)         1060
# 3               (Mary) Haiy          126
# 4       -TheQueensCornerLot          150

# %%
# find top five host best on their turnover
top_five=top_host.sort_values('total_price',ascending=False).iloc[:5,:5]
top_five
# Out:
#          host_name  total_price
# 9781  Sonder (NYC)        82795
# 1356    Blueground        70331
# 7135       Michael        66895
# 2376         David        65844
# 314           Alex        52563

# %%
fig = px.bar(top_five, x='host_name', y='total_price', text_auto='.2s',title="Top Five Host According To Their Turnover",width=700, height=500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 4
# Where the customer pays the highest and lowest rent according to location?

# %%
#Now we will create a dataframe of Highest rent according to the location

max_price_df = df.groupby('neighbourhood_group',as_index=False)['price'].max().sort_values(['price'],ascending = False).rename(columns = {'price':'Maximum price','neighbourhood_group':'Location'})
max_price_df
# Out:
#         Location  Maximum price
# 1       Brooklyn          10000
# 2      Manhattan          10000
# 3         Queens          10000
# 4  Staten Island           5000
# 0          Bronx           2500

# %%
#Now we will create a dataframe of lowest rent according to the location
min_price_df = df.groupby('neighbourhood_group',as_index=False)['price'].min().sort_values(['price'],ascending = True).rename(columns = {'price':'Minimum price','neighbourhood_group':'Location'})
min_price_df
# Out:
#         Location  Minimum price
# 0          Bronx             10
# 1       Brooklyn             10
# 2      Manhattan             10
# 3         Queens             10
# 4  Staten Island             13

# %%
#now we will combine the both  dataframe of minimum and maximum price according to location
merge_price_df = pd.merge(max_price_df, min_price_df, on='Location')
merge_price_df
# Out:
#         Location  Maximum price  Minimum price
# 0       Brooklyn          10000             10
# 1      Manhattan          10000             10
# 2         Queens          10000             10
# 3  Staten Island           5000             13
# 4          Bronx           2500             10

# %%
fig = px.bar(merge_price_df, x='Location', y=['Maximum price','Minimum price'], text_auto='.2s',title="Top Five Host According To Their Turnover",width=800, height=500,barmode='group')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 5
# What is the average preferred price by customers according to the location?

# %%
#we will find the average_price of property according to the location
avg_preffered_price = df.groupby(['neighbourhood_group','room_type'], as_index=False)['price'].mean()

#now we will change the column name
avg_preffered_price = avg_preffered_price.rename(columns={'neighbourhood_group':'Location','price':'Average Price'})
avg_preffered_price

# %%
#Now we will Unstack the group by information for plotting in  the graph
avg_preffered_price = avg_preffered_price.groupby(['Location','room_type'])['Average Price'].mean().unstack()
avg_preffered_price

# %%
fig = px.bar(avg_preffered_price,  text_auto='.2s',title="Average preferred price by customers according to the location",width=1000, height=500,barmode='group')
fig.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 6
# Top 3 Most Popular host of Airbnb

# %%
#we will create a dataframe of the host based on number of reviews
host_based_on_review = df.groupby(['host_name'],as_index=False)['number_of_reviews'].sum().sort_values(['number_of_reviews'],ascending = False)
host_based_on_review
# Out:
#       host_name  number_of_reviews
# 7135    Michael              11081
# 2376      David               8103
# 4989       John               7223
# 4634      Jason               6522
# 314        Alex               6204
# ...         ...                ...
# 5671      Kirby                  0
# 9519       Shei                  0
# 9515   Sheethal                  0
# 699      Anjeza                  0
# 11452        현선                  0
#
# [11453 rows x 2 columns]

# %%
#now we will create a dataframe of  the host based on availability in a year
host_based_on_availability = df.groupby(['host_name'],as_index=False)['availability_365'].mean().sort_values(['availability_365'],ascending = True)
host_based_on_availability
# Out:
#            host_name  availability_365
# 10333           Tide               0.0
# 7543           Naeem               0.0
# 7542           Nadya               0.0
# 7540           Nadja               0.0
# 3171         Everett               0.0
# ...              ...               ...
# 6502            Magd             365.0
# 6548      Majidudeen             365.0
# 6595         Mandela             365.0
# 6080   Lex And Derek             365.0
# 11452             현선             365.0
#
# [11453 rows x 2 columns]

# %%
#Now we will merge both dataframe  on host name
popular_host_df = pd.merge(host_based_on_review,host_based_on_availability,on = ['host_name']).sort_values(['availability_365','number_of_reviews'],ascending = [True,False])
#here we will change the column name
popular_host_df = popular_host_df.rename(columns = {'availability_365':'Availability in a year'})

popular_host_df
# Out:
#              host_name  number_of_reviews  Availability in a year
# 153    Gurpreet  Singh               1157                     0.0
# 533     Emily And Joel                423                     0.0
# 661     Andy & Friends                348                     0.0
# 677          En & Lora                341                     0.0
# 781             Dragan                304                     0.0
# ...                ...                ...                     ...
# 11423           Kettly                  0                   365.0
# 11424            Shiri                  0                   365.0
# 11427          Shining                  0                   365.0
# 11449             Shei                  0                   365.0
# 11452               현선                  0                   365.0
#
# [11453 rows x 3 columns]

# %%
#top 5 hosts based on popularity
popular_host_df.head(5)
# Out:
#            host_name  number_of_reviews  Availability in a year
# 153  Gurpreet  Singh               1157                     0.0
# 533   Emily And Joel                423                     0.0
# 661   Andy & Friends                348                     0.0
# 677        En & Lora                341                     0.0
# 781           Dragan                304                     0.0

# %%
#Create scatter plot based on number of reviews and availability in a year
popular_host_df.plot.scatter(x='number_of_reviews', y='Availability in a year', xlim=(100,1000),ylim=(10,380));

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 7
# Number. of active host per location (Where most of the host focused to own property)

# %%
#Here we will apply group by operation on neighbourhood_group for find the number of host according to location
number_of_host = df.groupby('neighbourhood_group',as_index=False)['host_id'].count()
number_of_host=number_of_host.rename(columns={'neighbourhood_group':'Location','host_id':'Host'})
number_of_host
# Out:
#         Location   Host
# 0          Bronx   1091
# 1       Brooklyn  20104
# 2      Manhattan  21661
# 3         Queens   5666
# 4  Staten Island    373

# %%
fig = px.line(number_of_host, x="Location", y="Host", title='Number of hosts per location',height=500, width=1000)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8
# Find total no. of nights spend per location

# %%
#  Here we will find the maximum number of minimum nights spent by customer in different neighourhood group
total_nights=df.groupby('neighbourhood_group')['minimum_nights'].sum().reset_index()
total_nights=total_nights.rename(columns={'neighbourhood_group':'Location','minimum_nights':'Nights'})
total_nights=total_nights.sort_values('Nights',ascending=True)
total_nights.head()
# Out:
#         Location  Nights
# 4  Staten Island    1802
# 0          Bronx    4976
# 3         Queens   29358
# 1       Brooklyn  121761
# 2      Manhattan  185833

# %%
fig = px.bar(total_nights, x='Location', y='Nights', height=500, width=800)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9
# Top 10 highest listing neighbourhood

# %%
# Finding unique values from column neighborhood
neighborhood = df.neighbourhood.unique()
neighborhood

# %%
neighborhood

# %%
#Finding the count of every neighbourhood
neighbourhood_frequency = dict(df.neighbourhood.value_counts())
neighbourhood_frequency

# %%
# Creating New Dataframe from dictionary
neighbourhood_frequency_df=pd.DataFrame(list(neighbourhood_frequency.items()),columns = ['Neighbourhood', 'Count'])
neighbourhood_frequency_df
# Out:
#           Neighbourhood  Count
# 0          Williamsburg   3920
# 1    Bedford-Stuyvesant   3714
# 2                Harlem   2658
# 3              Bushwick   2465
# 4       Upper West Side   1971
# ..                  ...    ...
# 216      Fort Wadsworth      1
# 217        Richmondtown      1
# 218            New Dorp      1
# 219           Rossville      1
# 220         Willowbrook      1
#
# [221 rows x 2 columns]

# %%
# now we will select the top 10 neighbourhood and create a new dataframe
top_ten_neighbourhood=neighbourhood_frequency_df.head(10)
top_ten_neighbourhood
# Out:
#         Neighbourhood  Count
# 0        Williamsburg   3920
# 1  Bedford-Stuyvesant   3714
# 2              Harlem   2658
# 3            Bushwick   2465
# 4     Upper West Side   1971
# 5      Hell's Kitchen   1958
# 6        East Village   1853
# 7     Upper East Side   1798
# 8       Crown Heights   1564
# 9             Midtown   1545

# %%
fig = px.bar(top_ten_neighbourhood, y='Count', x='Neighbourhood',text='Count', height=500, width=1000)
fig.update_traces(texttemplate='%{text:.3s}', textposition='outside')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### **Visualizing all listing’s room type proportions from each neighbourhood group**

# %%
import plotly.offline as pyo
import plotly.graph_objs as go

#Setting up the color pallete
color_dict = {'Private room': '#cc5a49', 'Entire home/apt' : '#4586ac', 'Shared room' : '#C0C0C0'}

#Grouping the room type using 'neighbourhood_group' as an index
airbnb_types=df.groupby(['neighbourhood_group', 'room_type']).size()

#Creating function to plot room type proportion on all region area
for region in df.neighbourhood_group.unique():

    plt.figure(figsize=(24,12))

    airbnb_reg=airbnb_types[region]
    labels = airbnb_reg.index
    sizes = airbnb_reg.values


    plot_num = 321
    plt.subplot(plot_num)
    reg_ch = go.Figure(data = [go.Pie(labels = labels, values = sizes, hole = 0.6)])
    reg_ch.update_traces(title = region, textfont_size=15, titlefont_size=25)
    reg_ch.update_layout(legend=dict(yanchor="top",y=0.99,xanchor="left",x=0.10,))
    reg_ch.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
